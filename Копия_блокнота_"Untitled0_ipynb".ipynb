# %% [markdown]
# <a href="https://colab.research.google.com/github/olegantoshel-cmd/anntoshel.github.io/blob/main/%D0%9A%D0%BE%D0%BF%D0%B8%D1%8F_%D0%B1%D0%BB%D0%BE%D0%BA%D0%BD%D0%BE%D1%82%D0%B0_%22Untitled0_ipynb%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Это ячейка кода - нажмите Ctrl+Enter для выполнения
print("Привет, Google Colab!")
# Out:
# Привет, Google Colab!

# %%
# Базовые арифметические операции
a = 15
b = 4

print("Сложение:", a + b)
print("Вычитание:", a - b)
print("Умножение:", a * b)
print("Деление:", a / b)
print("Целочисленное деление:", a // b)
print("Остаток от деления:", a % b)
print("Возведение в степень:", a ** b)
# Out:
# Сложение: 19
# Вычитание: 11
# Умножение: 60
# Деление: 3.75
# Целочисленное деление: 3
# Остаток от деления: 3
# Возведение в степень: 50625

# %%
# Базовые арифметические операции
a = 15
b = 4

a = 5
b = 10.2
c = 2 + 10j
d = 'какой-то текст'

print('Тип переменной а: ',type(a))
print('Тип переменной b: ', type(b))
print('Тип переменной c: ',type(c))
print('Тип переменной d: ', type(d))
# Out:
# Тип переменной а:  <class 'int'>
# Тип переменной b:  <class 'float'>
# Тип переменной c:  <class 'complex'>
# Тип переменной d:  <class 'str'>

# %%
def say_hi (name):
  return f'Привет, {name}! Добро пожаловать в мир программирования!'

print(say_hi("Анна"))
print(say_hi("Иван"))
# Out:
# Привет, Анна! Добро пожаловать в мир программирования!
# Привет, Иван! Добро пожаловать в мир программирования!

# %%
name = input("Введите имя:")
print(say_hi(name))

# %%
def define_status(age):
  if age < 18:
    return 'несовершеннолетний'
  elif age < 60:
    return 'взрослый'
  else:
    return 'пенсионер'

age = input('Введите свой возраст:')
print(type(age))
print(f'Ваш возраст: {age}, вы {define_status(int(age))}')

# %%
import random

#настройка диапазона и максимального кол-тва попыток
max_attempts = 7
min_range = 1
max_range = 100

secret_number = random.randint(min_range, max_range)
attempts = 1

print(f"Я загадал число от {min_range} до {max_range}")
print(f"У вас есть {max_attempts} попыток!")

while True:

  guess = int(input("Ваше предположение: "))

  if guess == secret_number:
     print(f"\n🎉 Поздравляю! Вы угадали число {secret_number}!")
     print(f"📊 Использовано попыток: {attempts}")
     break
  elif guess < secret_number:
      print("📈 Загаданное число БОЛЬШЕ")
  else:
      print("📉 Загаданное число МЕНЬШЕ")


  if attempts < max_attempts:
    print(f"💡 Осталось попыток: {max_attempts - attempts}")
    attempts +=1
  else:
    print(f"\n💀 Game Over! Вы исчерпали все попытки.")
    print(f"🔢 Загаданное число было: {secret_number}")
    break

# %%
a = float(input("Число 1: "))
b = float(input("Число 2: "))
op = input("Действие: ")

if op == "+": print(a + b)
if op == "-": print(a - b)
if op == "*": print(a * b)
if op == "/": print(a / b)

# %%
import random
import string

# Минимальный генератор
length = int(input("Длина: "))
chars = string.ascii_letters + string.digits + "!@#$%"
count = int(input("Количество: "))

print("\nПароли:")
for i in range(count):
    print(''.join(random.choice(chars) for _ in range(length)))
